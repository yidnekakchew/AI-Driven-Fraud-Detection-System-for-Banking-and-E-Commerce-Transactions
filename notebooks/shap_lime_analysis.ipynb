# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.shap_lime_analysis import *

# %%
run_analyses()
# Out:
# Analyzing Fraud Detection Models...
#
# Analyzing ../models/random_forest_fraud_model.pkl
# SHAP Summary Plot for Fraud Model - ../models/random_forest_fraud_model.pkl
# SHAP Force Plot for Fraud Model - ../models/random_forest_fraud_model.pkl (first instance)
# Error generating force plot: In v0.20, force plot now requires the base value as the first parameter! Try shap.plots.force(explainer.expected_value, shap_values) or for multi-output models try shap.plots.force(explainer.expected_value[0], shap_values[..., 0]).
# LIME Feature Importance Plot for Fraud Model - ../models/random_forest_fraud_model.pkl (first instance)
# Analyzing ../models/decision_tree_fraud_model.pkl
# SHAP Summary Plot for Fraud Model - ../models/decision_tree_fraud_model.pkl
# SHAP Force Plot for Fraud Model - ../models/decision_tree_fraud_model.pkl (first instance)
# Error generating force plot: too many indices for array: array is 1-dimensional, but 2 were indexed
# ...
