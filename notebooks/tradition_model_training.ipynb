# %%
scripts_path = '/content/drive/MyDrive/credit_fraud_model_training'
# Add the correct scripts folder path
import sys
sys.path.append(scripts_path)

# %%
from traditional_model_training import *

# %%
# Define the paths to your datasets (located in /kaggle/input)
credit_card_data_path = '/content/drive/MyDrive/credit_fraud_model_training/cleaned_creditcard.csv'
fraud_data_path = '/content/drive/MyDrive/credit_fraud_model_training/cleaned_merged_fraud.csv'

# Create an instance of the ModelTraining class
trainer = ModelTraining(credit_card_data_path, fraud_data_path)

# Prepare the data
trainer.data_preparation()
# Out:
# Initializing ModelTraining with datasets /content/drive/MyDrive/credit_fraud_model_training/cleaned_creditcard.csv and /content/drive/MyDrive/credit_fraud_model_training/cleaned_merged_fraud.csv

# %%
# Train models on creditcard data
trainer.train_creditcard_models()
# Out:
# Training Logistic Regression on Credit Card dataset...
#
# Logistic Regression on Credit Card Dataset Results:
# Accuracy: 0.9993
# Precision: 0.8776
# Recall: 0.6324
# F1-score: 0.7350
# ROC-AUC: 0.9782
# PR-AUC: 0.7876
# ...
# Training Decision Tree on Credit Card dataset...
#
# Decision Tree on Credit Card Dataset Results:
# Accuracy: 0.9995
# Precision: 0.8852
# Recall: 0.7941
# F1-score: 0.8372
# ROC-AUC: 0.9340
# PR-AUC: 0.7992
# ...
# Training Random Forest on Credit Card dataset...
#
# Random Forest on Credit Card Dataset Results:
# Accuracy: 0.9995
# Precision: 0.9286
# Recall: 0.7647
# F1-score: 0.8387
# ROC-AUC: 0.9754
# PR-AUC: 0.8482
# ...

# %%
# Train models on fraud data
trainer.train_fraud_models()
# Out:
# Training Logistic Regression on Fraud dataset...
#
# Logistic Regression on Fraud Dataset Results:
# Accuracy: 0.6531
# Precision: 0.1708
# Recall: 0.7057
# F1-score: 0.2750
# ROC-AUC: 0.7677
# PR-AUC: 0.5593
# ...
# Training Decision Tree on Fraud dataset...
#
# Decision Tree on Fraud Dataset Results:
# Accuracy: 0.9190
# Precision: 0.5659
# Recall: 0.5661
# F1-score: 0.5660
# ROC-AUC: 0.7713
# PR-AUC: 0.6158
# ...
# Training Random Forest on Fraud dataset...
#
# Random Forest on Fraud Dataset Results:
# Accuracy: 0.9513
# Precision: 0.8887
# Recall: 0.5460
# F1-score: 0.6764
# ROC-AUC: 0.7769
# PR-AUC: 0.6303
# ...
