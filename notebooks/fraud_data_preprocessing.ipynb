# %% [markdown]
# # Introduction
# This notebook provides an overview of the preprocessing steps applied to the Fraud Detection dataset, highlighting key insights and setting the stage for further analysis and modeling.

# %% [markdown]
# ### Adjusting Python Path to Include Parent Directory
# The next code cell Adjusts the Python path so that modules or packages located in the parent directory can be imported into the current script

# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %% [markdown]
# ### Importing Preprocessing class from the Scripts Module

# %%
from scripts.data_preprocessing import pre_processing

# %% [markdown]
# ### Data Preprocessing Overview: Instantiating the Class with fraud_data.csv

# %%
overview = pre_processing('../data/Fraud_Data.csv')

# %% [markdown]
# ### Data Overview and Initial Insights
# - This cell handles loading the fraud dataset and providing a summary of their structure.

# %%
overview.data_overview()
# Out:
# Shape of the dataset: (151112, 11)
#
# Preview of the first 5 rows:
#    user_id          signup_time        purchase_time  purchase_value  \
# 0    22058  2015-02-24 22:55:49  2015-04-18 02:47:11              34
# 1   333320  2015-06-07 20:39:50  2015-06-08 01:38:54              16
# 2     1359  2015-01-01 18:52:44  2015-01-01 18:52:45              15
# 3   150084  2015-04-28 21:13:25  2015-05-04 13:54:50              44
# 4   221365  2015-07-21 07:09:52  2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0
# Data types of the dataset
# user_id             int64
# signup_time        object
# purchase_time      object
# purchase_value      int64
# device_id          object
# source             object
# browser            object
# sex                object
# age                 int64
# ip_address        float64
# class               int64
# dtype: object
# Missing values of the dataset:
# Missing values in the dataset (Count and percentage)
#                 Missing Values Count  Missing Values Percentage (%)
# user_id                            0                            0.0
# signup_time                        0                            0.0
# purchase_time                      0                            0.0
# purchase_value                     0                            0.0
# device_id                          0                            0.0
# source                             0                            0.0
# browser                            0                            0.0
# sex                                0                            0.0
# age                                0                            0.0
# ip_address                         0                            0.0
# class                              0                            0.0

# %% [markdown]
# ### Data Cleaning and Preprocessing Steps
# - This cell focuses on cleaning the data by removing duplicate entries and addressing any missing values.

# %%
overview.data_cleaning()

# %% [markdown]
# ### Selection of Relevant Features for Analysis

# %%
overview.get_suitable_columns()
# Out:
# ['purchase_value', 'source', 'browser', 'sex', 'age', 'class']

# %% [markdown]
# ### Univariate Analysis: Exploring Individual Features
# - This cell conducts a univariate analysis of key features, including transaction amounts and the distribution of fraud classes.

# %%
overview.univariate_analysis()
# Out:
# Univariate Analysis for: purchase_value
# count    151112.000000
# mean         36.935372
# std          18.322762
# min           9.000000
# 25%          22.000000
# 50%          35.000000
# 75%          49.000000
# max         154.000000
# Name: purchase_value, dtype: float64
#
# Univariate Analysis for: source
# source
# SEO       60615
# Ads       59881
# Direct    30616
# Name: count, dtype: int64
#
# Univariate Analysis for: browser
# browser
# Chrome     61432
# IE         36727
# Safari     24667
# FireFox    24610
# Opera       3676
# Name: count, dtype: int64
#
# Univariate Analysis for: sex
# sex
# M    88293
# F    62819
# Name: count, dtype: int64
#
# Univariate Analysis for: age
# count    151112.000000
# mean         33.140704
# std           8.617733
# min          18.000000
# 25%          27.000000
# 50%          33.000000
# 75%          39.000000
# max          76.000000
# Name: age, dtype: float64
#
# Univariate Analysis for: class
# count    151112.000000
# mean          0.093646
# std           0.291336
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: class, dtype: float64

# %% [markdown]
# ### Bivariate Analysis: Investigating Relationships Between Features

# %%
overview.bivariate_analysis()

# %% [markdown]
# ###  Exporting Cleaned Data to CSV Format

# %%
overview.df.to_csv('../data/Processed_Fraud_Data.csv', index = False)
